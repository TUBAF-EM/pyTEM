# %% [markdown]
# # Using the TEM class for data inversion
# ## Central-loop soundings with sTEM
#
# We make use of the data published by Madsen et al. (2026), made publicly available on [Zenodo](https://doi.org/10.5281/zenodo.16894039). Here we focus on the central-loop data with 40x40 and 80x80m loops.
#
# We import the main class `TEM`.

# %%
from pytem import TEM

# %% [markdown]
# The instance is instantiated through the data file name. Instead of the USF files, we chose the xyz data files as it includes all soundings in one go. Whereas the data are in the xyz file, a gex file is exported containing the geometry of the loops, the time gates and the current waveform. If a file with the same name like the xyz file but the ending gex is found, it is read by default. Alternatively, you can specify this file explicitly by `cfg=`.

# %%
tem40 = TEM("40x40.xyz")
print(tem40)
# Out:
# TEM profile with 20 soundings
# 47 times (1.245463e-05-0.01112942)

# %%
tem40.cfg
# Out:
# {'rxpos': array([ 0.,  0., -0.]),
#  'txpos': array([ 0.,  0., -0.]),
#  'txarea': array([1600.]),
#  'tx': array([ 20., -20., -20.,  20.]),
#  'ty': array([ 20.,  20., -20., -20.]),
#  'tL': array([-2.85000e-03, -2.75507e-03, -2.63939e-03, -2.53554e-03,
#         -2.45798e-03, -2.31864e-03, -2.13723e-03, -1.95000e-03,
#         -1.94979e-03, -1.94938e-03, -1.94918e-03, -1.94891e-03,
#         -1.94842e-03, -1.94798e-03, -1.94754e-03, -1.94688e-03,
#         -1.94591e-03, -1.94474e-03, -1.94300e-03, -9.00000e-04,
#         -8.05070e-04, -6.89390e-04, -5.85540e-04, -5.07980e-04,
#         -3.68640e-04, -1.87230e-04,  0.00000e+00,  2.07000e-07,
#          6.21000e-07,  8.21000e-07,  1.09300e-06,  1.57900e-06,
#          2.02100e-06,  2.46400e-06,  3.12100e-06,  4.09300e-06,
#          5.26400e-06,  7.00000e-06]),
#  'vL': array([-0.   , -0.365, -0.611, -0.756, -0.823, -0.916, -0.97 , -1.   ,
#         -0.989, -0.772, -0.712, -0.653, -0.401, -0.258, -0.152, -0.075,
#         -0.028, -0.011, -0.   ,  0.   ,  0.365,  0.611,  0.756,  0.823,
#          0.916,  0.97 ,  1.   ,  0.989,  0.772,  0.712,  0.653,  0.401,
#          0.258,  0.152,  0.075,  0.028,  0.011,  0.   ]),
#  'tH': array([-2.60000e-02, -2.59028e-02, -2.56915e-02, -2.55056e-02,
#         -2.52775e-02, -2.50070e-02, -2.46268e-02, -2.41535e-02,
#         -2.22014e-02, -2.00000e-02, -1.99997e-02, -1.99991e-02,
#         -1.99984e-02, -1.99979e-02, -1.99973e-02, -1.99962e-02,
#         -1.99952e-02, -1.99942e-02, -1.99933e-02, -1.99922e-02,
#         -1.99901e-02, -1.99870e-02, -6.00000e-03, -5.90280e-03,
#         -5.69150e-03, -5.50560e-03, -5.27750e-03, -5.00700e-03,
#         -4.62680e-03, -4.15350e-03, -2.20140e-03,  0.00000e+00,
#          3.45000e-07,  8.93000e-07,  1.56000e-06,  2.10700e-06,
#          2.65500e-06,  3.77400e-06,  4.84500e-06,  5.79800e-06,
#          6.65500e-06,  7.75000e-06,  9.86900e-06,  1.30000e-05]),
#  'vH': array([-0.   , -0.306, -0.671, -0.829, -0.925, -0.971, -0.994, -0.999,
#         -1.   , -0.997, -0.927, -0.88 , -0.733, -0.646, -0.53 , -0.323,
#         -0.15 , -0.062, -0.03 , -0.015, -0.006, -0.   ,  0.   ,  0.306,
#          0.671,  0.829,  0.925,  0.971,  0.994,  0.999,  1.   ,  0.997,
#          0.927,  0.88 ,  0.733,  0.646,  0.53 ,  0.323,  0.15 ,  0.062,
#          0.03 ,  0.015,  0.006,  0.   ]),
#  'timeL': array([1.245463e-05, 1.551179e-05, 1.931937e-05, 2.406156e-05,
#         2.996779e-05, 3.732379e-05, 4.648541e-05, 5.789587e-05,
#         7.210718e-05, 8.980685e-05, 1.118511e-04, 1.393065e-04,
#         1.735011e-04, 2.160893e-04, 2.691313e-04, 3.351932e-04,
#         4.174709e-04, 5.199446e-04, 6.475720e-04, 8.065272e-04]),
#  'timeH': array([3.133530e-05, 3.927603e-05, 4.922905e-05, 6.170427e-05,
#         7.734087e-05, 9.693996e-05, 1.215057e-04, 1.522967e-04,
#         1.908905e-04, 2.392644e-04, 2.998968e-04, 3.758942e-04,
#         4.711503e-04, 5.905453e-04, 7.401965e-04, 9.277711e-04,
#         1.162879e-03, 1.457567e-03, 1.826931e-03, 2.289898e-03,
#         2.870185e-03, 3.597523e-03, 4.509179e-03, 5.651858e-03,
#         7.084105e-03, 8.879302e-03, 1.112942e-02])}

# %%
tem80 = TEM("80x80.xyz") # , cfg="data/madsen2026/40x40.gex")
print(tem80)
# Out:
# TEM profile with 3 soundings
# 47 times (1.871522e-05-0.02379088)

# %%
ax = tem40.showWaveform();

# %%
ax = tem80.showWaveform();

# %%
ax = tem40.showWaveform(label="40x40")
tem80.showWaveform(ax=ax, label="80x80")
ax.set_xlim(0, 20)
ax.set_ylim(0, 1)
# Out:
# (0.0, 1.0)
